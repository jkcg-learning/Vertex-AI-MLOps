# %% [markdown]
# # MLOPs in Deep Learning Projects using Vertex AI
#
# - Jyothish CHANDRASENAN

# %% [markdown]
# ## Dataset Component
#
# - Where data is stored (Google Cloud Storage or private cloud)
# - Annotation details corresponding to Computer vision task
# - Annotation Format (COCO, YOLO, Pascal VOC, others etc...)

# %% [markdown]
# ## Model Experimentation
#
# https://cloud.google.com/vertex-ai/docs/experiments/intro-vertex-ai-experiments
#
# - Using Vertex AI Experiments and TensorBoard Instance
# - can leverage the feature of MLFlow's Autologging feature supported for frameworks Tensorflow, PyTorch, Scikit-Learn etc
#
#
# ![image.png](attachment:68ad7844-23bd-4caa-96d7-5b8f711341e9.png)

# %% [markdown]
# ## Training Component
#
# ### Machine Cofiguration
#
# https://cloud.google.com/vertex-ai/docs/pipelines/machine-types

# %% [markdown]
# component.(set_cpu_limit('CPU_LIMIT').
#     set_memory_limit('MEMORY_LIMIT').
#     add_node_selector_constraint(SELECTOR_CONSTRAINT).
#     set_gpu_limit(GPU_LIMIT))

# %% [markdown]
# ![image.png](attachment:b29a0206-9490-41a0-9d0a-d47ab96799a9.png)

# %% [markdown]
# ![image.png](attachment:105d4c02-db9b-4b20-bb88-64dd6fc7fb70.png)

# %% [markdown]
# ![image.png](attachment:ccad9b30-98c3-49ec-b1c6-f8860395d5df.png)

# %% [markdown]
# ## Serving and Deployment Component
#
# ### Configuration
#
# https://cloud.google.com/vertex-ai/docs/predictions/using-nvidia-triton

# %% [markdown]
# ![image.png](attachment:9c68d1a7-ac22-43a6-98dd-2aa8552b1630.png)

# %% [markdown]
# ![image.png](attachment:b23954ba-a748-4571-badb-8f5e5345ef96.png)

# %% [markdown]
# ![image.png](attachment:437dabe3-da90-4651-87d5-637340d8d2c7.png)

# %% [markdown]
# ## Model Monitoring

# %% [markdown]
# ![image.png](attachment:c79f7bf3-e2a4-4ae5-a7f0-00c52b1b6e55.png)

# %% [markdown]
# https://github.com/triton-inference-server/server/blob/r20.12/docs/metrics.md

# %% [markdown]
# ![image.png](attachment:a172d3d0-ab78-4ee3-9294-4156ee4bf875.png)

# %% [markdown]
# ## Pricing
#
# https://cloud.google.com/vertex-ai/pricing

# %% [markdown]
# ![image.png](attachment:826e6970-5d20-478b-9887-0b779c1c025d.png)

# %% [markdown]
# ![image.png](attachment:80a68b4a-89c8-4ece-8858-557c260bf198.png)
